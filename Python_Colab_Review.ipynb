# %% [markdown]
# <a href="https://colab.research.google.com/github/trongminh13/AI-chatbot-Coffee-Shop-Customer-Service/blob/main/Python_Colab_Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch import nn # import torch.nn as nn

# %%
x = 5
y = 6
x,y = 5,6
print(x)
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
def add_mult_2(a,b):
  return 2*(a+b)

# %%
add_mult_2(1,2)
# Out:
# 6

# %%
class Net(nn.Module):
  def __init__(self, input_sz=1):
    super(Net,self).__init__()
    self.layer = nn.Linear(input_sz,1)
    self.input_sz = input_sz
  def forward(self,x):
    x = self.layer(x)
    return x
model = Net(input_sz=10)

model2 = Net()

model2.input_sz

input = torch.tensor(2.).unsqueeze(0)
input
model2.forward(input)
# Out:
# tensor([0.3686], grad_fn=<ViewBackward0>)

# %%
model2(input)
# Out:
# tensor([0.3686], grad_fn=<ViewBackward0>)

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
if (i < 2):
  print('yes')
else:
  print('no')
# Out:
# no

# %%
print('yes') if (i < 2) else print('no')
# Out:
# no

# %% [markdown]
# How to Load File

# %%
import requests

url = "https://upload.wikimedia.org/wikipedia/commons/3/3a/Cat03.jpg"

headers = {
    "User-Agent": "Mozilla/5.0"
}

r = requests.get(url, headers=headers)

with open("cat.jpg", "wb") as f:
    f.write(r.content)
